# %%
import numpy as np
arr = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])
arrone = 5 + arr
print(arrone)
print(arr.ndim)
print(arr.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import numpy as np
#       2 arr = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])
#       3 arrone = 5 + arr
#
# ModuleNotFoundError: No module named 'numpy'

# %%
arr = np.random.randn(5,4)
print(arr)
# Out:
# [[ 0.03782341 -0.04523008  0.12938312  0.18323677]
#  [-0.50960469 -1.72362889 -1.89263363  0.567588  ]
#  [ 1.22956461 -0.19186938 -3.7458549   0.82105323]
#  [-1.65394569 -1.22102435 -0.30734493 -0.57119052]
#  [ 1.33912896  0.2436745   1.31046584 -0.46773384]]
