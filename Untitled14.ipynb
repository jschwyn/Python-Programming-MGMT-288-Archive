# %%
import pandas as pd
df = pd.DataFrame({
    'Name': ['Joe', 'Harry', 'Lily', 'Alice'],
    'Status': ['Father', 'Son', 'Mother', 'Daughter'],
    'Birthyear': [1978, 1984, 2013, 2019]
})
df['age'] = df['Birthyear'].apply(lambda x: 2024 -x)
staus_to_gender
df
# Out:
#     Name    Status  Birthyear  age
# 0    Joe    Father       1978   46
# 1  Harry       Son       1984   40
# 2   Lily    Mother       2013   11
# 3  Alice  Daughter       2019    5
