# %%
import numpy as np

my_list = list(range(1000000))
my_arr = np.arange(1000000)

# %%
arr = np.array([1, 2, 3, 4])
print(arr[0])
print(arr[2] + arr[3])
# Out:
# 1
# 7

# %%
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
